# %%
import numpy as np
from matplotlib import pyplot as plt
import math
import csv
import random
import os

data = []

with open('shuffled_data.csv', "rt") as filereader:
    fil = csv.reader(filereader, delimiter= ' ' )
    for rows in fil:
        data.append(rows)

formated_data = []
i = 0
for da in data:
    if(i == 207):
        break
    i+=1
    da = da[0]
    da = da.split(",")
    data_new = []
    j  = 0
    for x in da:
        j+=1
        data_new.append(float(x))
        if( j == 60):
            break
    if(da[-1] == 'M'):
        data_new.append(1)
    else:
        data_new.append(0)
    formated_data.append(data_new)

rows = len(formated_data)
cols = len(formated_data[0])
    
    
for x in range(cols - 1):
    data = []
    met = []
    roc = []
    
    for index in range(rows - 1):
        data.append(formated_data[index][x])
        if formated_data[index][-1] == 1 : met.append(formated_data[index][x])
        else: roc.append(formated_data[index][x])

    path = os.getcwd()
    path += "/data_visualization/" + str(x)
    print(path)
    try : 
        os.mkdir(path)
    except OSError:
        print("sorry fails to create to directory ")
    else :
        print("scccesfully created directory ")
        
    plt.hist( np.array(data) )
    plt.title("columnn no or attribute no = " + str(x))
    plt.xlabel('attribute value ')
    plt.ylabel('frequency')
    
    gif1 = plt.gcf()    # get current figure 
    mlt.show()
    name =  "data_visualization/" +str(x) + "/" + str(x) + ".jpg"
    
    gif1.savefig(name)
    
    plt.hist( np.array(met), color = "cyan" )
    plt.title("column no  = " + str(x) + " metal")
    plt.xlabel('attribute value ')
    plt.ylabel('frequency')
    
    gif1 = plt.gcf()    # get current figure 
    mlt.show()
    name =  "data_visualization/" + str(x) + "/"+ "metal" +str(x) + ".jpg"
    
    gif1.savefig(name)
    
    plt.hist( np.array(roc), color = "brown" )
    plt.title("columnn no  = " + str(x) + " rocks ")
    plt.xlabel('attribute value ')
    plt.ylabel('frequency')
    
    gif1 = plt.gcf()    # get current figure 
    mlt.show()
    name =  "data_visualization/"+ str(x) + "/" + " rocks"  + str(x) + ".jpg"
    
    gif1.savefig(name)

data = []
for index in range(rows - 1):


    data.append(formated_data[index][-1])

plt.hist( np.array(data), color = "yellow" )
plt.title("data_set labels")
plt.xlabel('rock = 0    and   metal = 1')
plt.ylabel('frequency')

gif1 = plt.gcf()    # get current figure 
mlt.show()
name =   "data_set_distibution" + ".jpg"
gif1.savefig(name)
# Out:
# /home/ajay/PycharmProjects/decision_tree/data_visualization/0
# scccesfully created directory
# /home/ajay/PycharmProjects/decision_tree/data_visualization/1
# scccesfully created directory
# /home/ajay/PycharmProjects/decision_tree/data_visualization/2
# scccesfully created directory
# /home/ajay/PycharmProjects/decision_tree/data_visualization/3
# scccesfully created directory
# /home/ajay/PycharmProjects/decision_tree/data_visualization/4
# scccesfully created directory
# /home/ajay/PycharmProjects/decision_tree/data_visualization/5
# scccesfully created directory
# /home/ajay/PycharmProjects/decision_tree/data_visualization/6
# scccesfully created directory
# /home/ajay/PycharmProjects/decision_tree/data_visualization/7
# scccesfully created directory
# /home/ajay/PycharmProjects/decision_tree/data_visualization/8
# scccesfully created directory
# /home/ajay/PycharmProjects/decision_tree/data_visualization/9
# scccesfully created directory
# ...
